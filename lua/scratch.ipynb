-- %%
plot = Plot():line(x1, y1,'red','example'):legend(true):title('Line Plot Demo'):draw()
-- Out:
-- <script type="text/javascript">
-- $(function() {
--     if (typeof (window._bokeh_onload_callbacks) === "undefined"){
-- 	window._bokeh_onload_callbacks = [];
--     }
--     function load_lib(url, callback){
-- 	window._bokeh_onload_callbacks.push(callback);
-- 	if (window._bokeh_is_loading){
-- 	    console.log("Bokeh: BokehJS is being loaded, scheduling callback at", new Date());
-- 	    return null;
-- 	}
-- 	console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", new Date());
-- 	window._bokeh_is_loading = true;
-- 	var s = document.createElement('script');
-- 	s.src = url;
-- 	s.async = true;
-- 	s.onreadystatechange = s.onload = function(){
-- 	    Bokeh.embed.inject_css("http://cdn.pydata.org/bokeh-0.7.0.min.css");
-- 	    window._bokeh_onload_callbacks.forEach(function(callback){callback()});
-- 	};
-- 	s.onerror = function(){
-- 	    console.warn("failed to load library " + url);
-- 	};
-- 	document.getElementsByTagName("head")[0].appendChild(s);
--     }
--
--     bokehjs_url = "http://cdn.pydata.org/bokeh-0.7.0.min.js"
--
--     var elt = document.getElementById("49fd7e0a-99e4-42c9-c230-569e198fd904");
--     if(elt==null) {
-- 	console.log("Bokeh: ERROR: autoload.js configured with elementid '49fd7e0a-99e4-42c9-c230-569e198fd904'"
-- 		    + "but no matching script tag was found. ")
-- 	return false;
--     }
--
--     if(typeof(Bokeh) !== "undefined") {
-- 	console.log("Bokeh: BokehJS loaded, going straight to plotting");
-- 	var modelid = "f7004df0-ddf7-4d03-cdb8-4fa1de6e3bcf";
-- 	var modeltype = "Plot";
-- 	var all_models = [{"type":"ColumnDataSource","attributes":{"cont_ranges":{},"column_names":["x","y"],"data":{"y":[2.8999815073573,-19.517966615182,163.33123196908,-17.93558690149,-58.444703103798,102.92712359932,51.877846912697,-58.735056364417,-113.48431584573,74.208847904523,-10.608369870324,14.87003676945,33.765494443472,-105.59515834174,-48.213228665313,-14.098129163625,125.659060139,-6.6525768091082,38.868739574848,36.76546968518,-237.67245317195,-95.752392892643,46.891804713856,125.46324919437,93.847430591338,-22.285460790427,98.040778076496,-97.921894117375,-43.657259120516,49.656131829458,-41.994178911342,-195.60853311372,96.756070000806,4.7964094998037,36.93431389937,30.560389583939,-176.68759812958,-97.078955000868,-22.859818141115,31.935750660411],"x":[99.270626716803,125.75755334414,64.849173591518,-107.81345226025,55.457365258777,52.258051995638,28.498231294538,30.251626241136,-134.18367344977,124.72477944187,-17.506489012965,-46.149326267535,-16.851915084486,-105.25129085357,-81.090221364421,-32.153188534444,54.873370423489,-154.24830096912,34.729073270457,-50.93757892657,-82.166915324029,131.60704979907,6.2867568243086,97.289298008337,41.134462999856,21.039358425919,-90.967339641009,-69.980503348581,-188.42625528155,7.4481238340189,-24.853442666921,31.623602494056,-225.33760327306,23.663431445666,62.029473368468,-120.85336101055,-49.956916613588,12.129473036623,-223.31996078853,-190.92220067655]},"selected":[],"tags":[],"doc":null,"discrete_ranges":{},"id":"fc73a7e6-7404-4f02-cf0e-21bbb4c021ef"},"id":"fc73a7e6-7404-4f02-cf0e-21bbb4c021ef"},{"type":"Line","attributes":{"x":{"units":"data","field":"x"},"size":{"units":"screen","value":10},"id":"3341b4ae-cbb7-4b06-cb09-af6b68284b67","y":{"units":"data","field":"y"},"doc":null,"fill_color":{"value":"red"},"fill_alpha":{"units":"data","value":0.2},"line_alpha":{"units":"data","value":1},"tags":[],"line_color":{"value":"red"}},"id":"3341b4ae-cbb7-4b06-cb09-af6b68284b67"},{"type":"Line","attributes":{"x":{"units":"data","field":"x"},"size":{"units":"screen","value":10},"id":"4790005a-184c-44cd-c430-d44d8e4487c9","y":{"units":"data","field":"y"},"doc":null,"fill_color":{"value":"red"},"fill_alpha":{"units":"data","value":0.2},"line_alpha":{"units":"data","value":1},"tags":[],"line_color":{"value":"red"}},"id":"4790005a-184c-44cd-c430-d44d8e4487c9"},{"type":"GlyphRenderer","attributes":{"data_source":{"type":"ColumnDataSource","id":"fc73a7e6-7404-4f02-cf0e-21bbb4c021ef"},"id":"851d1b8b-11ef-4d4f-cd56-15c4c5291a50","server_data_source":null,"doc":null,"nonselection_glyph":{"type":"Line","id":"4790005a-184c-44cd-c430-d44d8e4487c9"},"glyph":{"type":"Line","id":"3341b4ae-cbb7-4b06-cb09-af6b68284b67"},"tags":[],"name":null,"selection_glyph":null},"id":"851d1b8b-11ef-4d4f-cd56-15c4c5291a50"},{"type":"DataRange1d","attributes":{"tags":[],"doc":null,"sources":[{"source":{"type":"ColumnDataSource","id":"fc73a7e6-7404-4f02-cf0e-21bbb4c021ef"},"columns":["x"]}],"id":"edb83bf6-05e3-44b6-c4a2-4de8e78dc2eb"},"id":"edb83bf6-05e3-44b6-c4a2-4de8e78dc2eb"},{"type":"DataRange1d","attributes":{"tags":[],"doc":null,"sources":[{"source":{"type":"ColumnDataSource","id":"fc73a7e6-7404-4f02-cf0e-21bbb4c021ef"},"columns":["y"]}],"id":"9ad64c8d-0dc1-490d-c9da-0dd82bac1e91"},"id":"9ad64c8d-0dc1-490d-c9da-0dd82bac1e91"},{"type":"ToolEvents","attributes":{"tags":[],"doc":null,"geometries":[],"id":"88fe02b4-c305-4443-c4bc-51a48e8ab53c"},"id":"88fe02b4-c305-4443-c4bc-51a48e8ab53c"},{"type":"BasicTickFormatter","attributes":{"tags":[],"doc":null,"id":"3de3aa81-2bc2-4514-c55b-552a597be5ee"},"id":"3de3aa81-2bc2-4514-c55b-552a597be5ee"},{"type":"BasicTicker","attributes":{"tags":[],"doc":null,"num_minor_ticks":5,"id":"30478146-1415-43bc-c354-2f11b7f63741"},"id":"30478146-1415-43bc-c354-2f11b7f63741"},{"type":"LinearAxis","attributes":{"plot":{"type":"Plot","subtype":"Figure","id":"f7004df0-ddf7-4d03-cdb8-4fa1de6e3bcf"},"ticker":{"type":"BasicTicker","id":"30478146-1415-43bc-c354-2f11b7f63741"},"id":"67fed ...

-- %%
Plot = require 'itorch.Plot'

-- %%
x1 = torch.randn(40):mul(100)
y1 = torch.randn(40):mul(100)
x2 = torch.randn(40):mul(100)
y2 = torch.randn(40):mul(100)
x3 = torch.randn(40):mul(200)
y3 = torch.randn(40):mul(200)

-- %%
n = nn.SpatialConvolution(1,64,16,16)

-- %%
require "nn"
-- Out:
-- true

-- %%
itorch.image(n.weight)
-- Out:
-- Console does not support images

-- %% [markdown]
-- ##
